# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ef99797112d1dbcf46dcf9e94318d878&language=en-US&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','vote_count','vote_average']]

# %%
df
# Out:
#         id                                         title  \
# 0      861                                  Total Recall
# 1   539617                          Big Time Adolescence
# 2   440596                                  Kiss and Cry
# 3   121642                                    Twice Born
# 4    75624      Naruto Shippuden the Movie: Blood Prison
# 5    65229                                        Tomboy
# 6    11886                                    Robin Hood
# 7    11426                         From Here to Eternity
# 8   498248                        Mia and the White Lion
# 9   318121                    The Fundamentals of Caring
# 10   45612                                   Source Code
# 11   15392                                    Crossroads
# 12       3                           Shadows in Paradise
# 13     813                                     Airplane!
# 14     764                                 The Evil Dead
# ...

# %%
df.sample(5)
# Out:
#         id                       title  \
# 0      861                Total Recall
# 18   49538          X-Men: First Class
# 13     813                   Airplane!
# 9   318121  The Fundamentals of Caring
# 14     764               The Evil Dead
#
#                                              overview release_date  \
# 0   Construction worker Douglas Quaid's obsession ...   1990-06-01
# 18  Before Charles Xavier and Erik Lensherr took t...   2011-06-01
# 13  An ex-fighter pilot forced to take over the co...   1980-07-02
# 9   Having suffered a tragedy, Ben becomes a careg...   2016-06-16
# 14  In 1979, a group of college students find a Su...   1981-09-10
#
#     vote_count  vote_average
# 0         5599         7.304
# 18       12450         7.300
# 13        4334         7.301
# 9         2126         7.302
# 14        3839         7.301

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,101):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ef99797112d1dbcf46dcf9e94318d878&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','vote_count','vote_average']]
    df = df._append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                                         title  \
# 0        278                      The Shawshank Redemption
# 1        238                                 The Godfather
# 2        240                         The Godfather Part II
# 3        424                              Schindler's List
# 4        389                                  12 Angry Men
# ...      ...                                           ...
# 1995  453395   Doctor Strange in the Multiverse of Madness
# 1996  432616                               Promise at Dawn
# 1997  297270  Tinker Bell and the Legend of the NeverBeast
# 1998   49538                            X-Men: First Class
# 1999   40794                                 Loose Cannons
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...

# %%
df.shape
# Out:
# (2000, 6)

# %%
df.to_csv('top_rated_movies.csv')
